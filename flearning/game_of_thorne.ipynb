# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
import matplotlib

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="639.0476480687299">

# %%
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)

# %%
import numpy as np
import pandas as pd

# %%
ax1.plot(np.random.randn(50).cumsum())

# %%
plt.plot(np.random.randn(50).cumsum())

# %%
plt.plot(np.random.randn(50).cumsum())

# %%
ax2.hist(np.random.rand(100),bins=50)
# Out:
# (array([ 5.,  4.,  2.,  3.,  0.,  3.,  2.,  1.,  1.,  1.,  2.,  0.,  1.,
#          2.,  2.,  5.,  1.,  3.,  0.,  3.,  3.,  2.,  0.,  2.,  6.,  1.,
#          3.,  0.,  3.,  0.,  2.,  1.,  4.,  4.,  0.,  1.,  2.,  4.,  0.,
#          4.,  1.,  2.,  1.,  3.,  1.,  2.,  0.,  1.,  2.,  4.]),
#  array([ 0.00316229,  0.02301701,  0.04287173,  0.06272645,  0.08258118,
#          0.1024359 ,  0.12229062,  0.14214534,  0.16200006,  0.18185479,
#          0.20170951,  0.22156423,  0.24141895,  0.26127367,  0.2811284 ,
#          0.30098312,  0.32083784,  0.34069256,  0.36054728,  0.38040201,
#          0.40025673,  0.42011145,  0.43996617,  0.45982089,  0.47967561,
#          0.49953034,  0.51938506,  0.53923978,  0.5590945 ,  0.57894922,
#          0.59880395,  0.61865867,  0.63851339,  0.65836811,  0.67822283,
#          0.69807756,  0.71793228,  0.737787  ,  0.75764172,  0.77749644,
#          0.79735117,  0.81720589,  0.83706061,  0.85691533,  0.87677005,
#          0.89662478,  0.9164795 ,  0.93633422,  0.95618894,  0.97604366,
#          0.99589839]),
#  <a list of 50 Patch objects>)
